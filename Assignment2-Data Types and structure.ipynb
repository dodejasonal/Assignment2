# %% [markdown]
# ###Theoritical Question
# Q1-What are data structures, and why are they important?
#
# Ans-data structure is a way of organising and storing data.
# They are important because it can be accessed and manipulated efficiently.
#
# Q2- Explain the difference between mutable and immutable data types with examples?
#
# Ans2-Mutuable means which can be modified ex List.Immutable means which cannot be modified ex.tuples.
#
# Q3-What are the main differences between lists and tuples in Python?
#
# Ans3-List can be modified therefore they are mutuable whereas tuples cannot be modified therefore they are immutable.
#
# Q4-= Describe how dictionaries store data?
#
# Ans4-It stores data in the form of Key Value Pair.
#
# Q5- Why might you use a set instead of a list in Python?
#
# Ans5-Set helps to remove the duplicate elements.
#
#
# Q6- What is a string in Python, and how is it different from a list?
#
# Ans6- String is a sequence of character whereas list is an ordered collection of elements that can be of any data type.
#
# Q7- How do tuples ensure data integrity in Python?
#
# Ans7- Tuples immutability ensures that the data stored in a tuple remains consistent throughout the program, preventing accidental changes to the data. For example, if you need to store constant values that should not change, a tuple guarantees that those values will remain unchanged, maintaining the integrity of your data.
#
# Q8- What is a hash table, and how does it relate to dictionaries in Python?
#
# Ans8- In Python, the dict type (dictionary) is implemented using a hash table internally. When you create a dictionary, it stores the keys in a way that allows for very efficient retrieval of the associated values, thanks to the underlying hash table structure.
#
# Q9-Can lists contain different data types in Python?
#
# Ans9-Yes lists can contain different data types in Python.
#
# Q10- Explain why strings are immutable in Python?
#
# Ans10-Strings in Python are immutable, meaning that once a string is created, its contents cannot be changed. This immutability is a design choice that provides several benefits, both in terms of performance and reliability.
#
#
# Q11- What advantages do dictionaries offer over lists for certain tasks?
#
# Ans11-Dictionaries offer distinct advantages over lists when
# 1-Data needs to be associated with a unique identifier (key-value pairs).
# 2-You need to ensure that keys are unique.
#
# Q12- Describe a scenario where using a tuple would be preferable over a list?
#
# Ans12-Tuple is used where data needs to be fixed ex- saving adhar and pan number of employees whereas in this case list cannot be used as it is immutable.
#
# Q13- How do sets handle duplicate values in Python?
#
# Ans13-Set is a unique collection of elements,it does not allow duplicate iteams while execution.
#
# Q14-How does the “in” keyword work differently for lists and dictionaries?
#
# Ans14- In lists, the in keyword checks if a value is present in the list.
# In dictionaries, the in keyword checks if a key is present in the dictionary. To check if a value is present in a dictionary, you must use .values().
#
# Q15-Can you modify the elements of a tuple? Explain why or why note?
#
# Ans15- Tuples are immutable, meaning that once created, their elements cannot be modified.
#
#
# Q16- What is a nested dictionary, and give an example of its use case?
#
# Ans16-A nested dictionary in Python is a dictionary where the values themselves can be dictionaries. In other words, a dictionary can contain other dictionaries as its values. ex-

# %%
d={"name":"sonal", "age":"25"}
d["age"]
# Out:
# '25'

# %% [markdown]
# Q17-Describe the time complexity of accessing elements in a dictionary?
#
# Ans17 In Python, dictionaries are implemented using hash tables, and the time complexity of accessing elements depends on the efficiency of hashing and managing collisions.
#
# Q18- In what situations are lists preferred over dictionaries?
#
# Ans18-List are used when you need to maintain order, use indices, store homogeneous data, perform sequential operations, or append items or when you don't need fast lookups by key, handle key-value pairs, or work with data that is best indexed by unique identifiers.
#
# Q19-Why are dictionaries considered unordered, and how does that affect data retrieval?
#
# Ans19-dictionaries are considered unordered in terms of their internal storage mechanism.Oredered and unordered does not effect data retrieval.
#
# Q20-Explain the difference between a list and a dictionary in terms of data retrieval.?
#
# Ans20-Use a list when you need an ordered collection and need to access elements by their position/index or iterate through elements in a sequence.
# Use a dictionary when you need fast lookups, insertions, and deletions by unique keys, and when the association between a key and its value is important.

# %%
##PRCATICAL QUESTIONS
#Q1-Write a code to create a string with your name and print it?
name="sonal"
print(name)
# Out:
# sonal

# %%
#Q2-Write a code to find the length of the string "Hello World"?
a="Hello World"
len(a)
# Out:
# 11

# %%
#Q3-Write a code to slice the first 3 characters from the string "Python Programming"?
a="Python Programming"
a[0:3]
# Out:
# 'Pyt'

# %%
#Q4-Write a code to convert the string "hello" to uppercase?
a="hello"
a.upper()
# Out:
# 'HELLO'

# %%
#Q5-Write a code to replace the word "apple" with "orange" in the string "I like apple"?
a="I like apple"
a.replace("apple","orange")
# Out:
# 'I like orange'

# %%
#Q6-Write a code to create a list with numbers 1 to 5 and print it?
a=[1,2,3,4,5]
a
# Out:
# [1, 2, 3, 4, 5]

# %%
#Q7-Write a code to append the number 10 to the list [1, 2, 3, 4]?
b=[1,2,3,4,5]
b.append(10)
b
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
#Q8-Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]?
a= [1,2,3,4,5]
a.remove(3)
a
# Out:
# [1, 2, 4, 5]

# %%
#Q9-Write a code to access the second element in the list ['a', 'b', 'c', 'd']?
a=["a","b","c","d"]
a[2]
# Out:
# 'c'

# %%
#Q10-Write a code to reverse the list [10, 20, 30, 40, 50].
a=[10,20,30,40,50]
a.reverse()
a
# Out:
# [50, 40, 30, 20, 10]

# %%
#Q11- Write a code to create a tuple with the elements 10, 20, 30 and print it?
a=(1,2,3)
a
# Out:
# (1, 2, 3)

# %%
#Q12- Write a code to access the first element of the tuple ('apple', 'banana', 'cherry')?
a=("apple","banana","cherry")
a[0]
# Out:
# 'apple'

# %%
#Q13-Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2)?
a=(1,2,3,2,4,2)
a.count(2)
# Out:
# 3

# %%
#Q14- Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').?
a=("dog","cat","rabbit")
a.index("cat")
# Out:
# 1

# %%
#Q15-Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').
a=("apple","orange","banana")
if "banana" in a:
  print("yes")
# Out:
# yes

# %%
#Q16- Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.?
a={1,2,3,4,5}
a
# Out:
# {1, 2, 3, 4, 5}

# %%
#Q17-Write a code to add the element 6 to the set {1, 2, 3, 4}.
a={1,2,3,4}
a.add(6)
a
# Out:
# {1, 2, 3, 4, 6}

# %%
#Q18- Write a code to create a tuple with the elements 10, 20, 30 and print it.?
a=(10,20,30)
a
# Out:
# (10, 20, 30)

# %%
#Q19- Write a code to access the first element of the tuple ('apple', 'banana', 'cherry').?
a=("apple","banana","cherry")
a[0]
# Out:
# 'apple'

# %%
#Q20- Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).
a=(1,2,3,2,4,2)
a.count(2)
# Out:
# 3

# %%
#Q21 Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
a=("dog","cat","rabbit")
a.index("cat")
# Out:
# 1

# %%
#Q22- Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').
a=("apple","orange","banana")
if "banana" in a:
  print("yes")
# Out:
# yes

# %%
#Q23-Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.?
a={1,2,3,4,5}
a
# Out:
# {1, 2, 3, 4, 5}

# %%
#Q24-Write a code to add the element 6 to the set {1, 2, 3, 4}.
a={1,2,3,4}
a.add(6)
a
# Out:
# {1, 2, 3, 4, 6}
